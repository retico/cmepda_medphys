# %% [markdown]
# <a href="https://colab.research.google.com/github/retico/cmepda_medphys/blob/master/L7_code/Hands-on/DL_classification_microcalcifications_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classification of lesions in Medical Physics
#
# The aim of this exercise is to create and train a simple Convolutional Neural Network (CNN) for deep-learning based classification of normal tissue vs. tissue cointaining microcalcification clusters in mammograms.
#
# Microcalcifications are tiny bright spots with diameter of few hundred microns, that are common findings in mammography. They appearance may be masked by the highly heterogenous breast tissue. While isolated microcalcifications are benign, when they occur grouped in clusters with suspicious morphology and distribution patterns, they are associated with the risk of malignancy.

# %% [markdown]
# Mammography (see the figure below) is a diagnostic imaging modality based on X-rays, with extremely high resolution. Typical pixel size nowadays is 50 microns or less.

# %% [markdown]
# ![cluster.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# We will build a CNN classifier capable to distinguish images containing small potions of normal tissue, form images containing micorcacification clusters. The image portions we will examine are slightly smaller than the rightmost picture in the figure above.
#
# If we set this classifier to scan sistematically  the whole mammogram, we would obtain an automated system for the detection and localization of microcalcification clusters.

# %% [markdown]
# ## Exercise objectives
#
# In this exercise you will learn how to:
#
#
# *   Load and visualize image data
# *   Define the CNN model
# *   Compile and train the CNN model on the training data
# *   Predict the labels of the validation/test data samples
# *   Calculate the classification accuracy
# *   Create the ROC curve and calculate the AUC
# *   Compare the performance of different models
#
#
# Additionally, if you have extra time now or when you get home, you will learn how to perform data augmentation.
#
# ## Remark
# The architecture of the CNN you will develop in this exercise can be trained on different kind of 2D images (with 1 color channel) even outside the medical imaging domain.

# %% [markdown]
# ## Description of the dataset
#
# The dataset we will use contains many image portions (60x60 pixels, corresponding to 5.1 mm x 5.1 mm) extracted from real mammograms, with radiological annotations, and converted into 8-bit grayscale images. These images may contain microcalcification clusters (label = 1) or normal breast tissue (label = 0).
#
# The available images are already partitioned in a train set and a test set, containing, respectively:
# - Train set (70% of the whole sample): 289 images with normal tissue and 267 images with microcalcification clusters;
# - Test set (30% of the whole sample): 125 images with normal tissue and 116 images with microcalcification clusters.
#
# The test set should always be left apart from the training procedure and used as an independent set to evaluate the classifier performance.

# %% [markdown]
# Examples of images containing microcalcalfication clusters:

# %% [markdown]
# ![micro.png](data:image/png;base64,...)

# %% [markdown]
# Examples of images representing normal breast tissue:

# %% [markdown]
# ![no_micro.png](data:image/png;base64,...)

# %% [markdown]
# #Importing the dataset

# %% [markdown]
# We download the zipped data archive from a webserver.

# %%
import os
if os.path.isfile('DL_class_data.tar.gz'):
    print ("File already exists... skipping download")
else:
    print ("Downloading File")
    # !wget https://www.pi.infn.it/~boccali/DL_class_data.tar.gz
# Out:
# Downloading File
# --2023-12-09 17:24:44--  https://www.pi.infn.it/~boccali/DL_class_data.tar.gz
# Resolving www.pi.infn.it (www.pi.infn.it)... 212.189.152.86
# Connecting to www.pi.infn.it (www.pi.infn.it)|212.189.152.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2078720 (2.0M) [application/x-gzip]
# Saving to: ‘DL_class_data.tar.gz’
#
# DL_class_data.tar.g 100%[===================>]   1.98M  1.71MB/s    in 1.2s
#
# 2023-12-09 17:24:46 (1.71 MB/s) - ‘DL_class_data.tar.gz’ saved [2078720/2078720]

# %% [markdown]
# Now let's extract the archive.
#
# NB: Using the special ```!``` charcter we can execute shell commands.

# %%
# !tar -xvf DL_class_data.tar.gz
# Out:
# README_micro.rtf
# Test/
# Test/0/
# Test/0/0036t1_4_0_1.png
# Test/0/0035p1_3_0_3.png
# Test/0/0035t1_2_0_4.png
# Test/0/0039n1_2_0_4.png
# Test/0/0038t1_1_0_3.png
# Test/0/0032t1_4_0_1.png
# Test/0/0033f1_4_0_4.png
# Test/0/0039p1_3_0_3.png
# Test/0/0032f1_4_0_1.png
# Test/0/0032p1_1_0_4.png
# Test/0/0033t1_4_0_4.png
# Test/0/0035t1_4_0_3.png
# Test/0/0033f1_2_0_4.png
# Test/0/0035t1_4_0_2.png
# Test/0/0037p1_3_0_3.png
# Test/0/0038t1_3_0_2.png
# Test/0/0033t1_3_0_3.png
# Test/0/0033t1_4_0_2.png
# Test/0/0032f1_2_0_1.png
# Test/0/0038t1_1_0_2.png
# Test/0/0032t1_4_0_4.png
# Test/0/0039p1_1_0_2.png
# Test/0/0035t1_4_0_4.png
# Test/0/0034p1_3_0_2.png
# Test/0/0032f1_1_0_4.png
# Test/0/0032p1_3_0_4.png
# Test/0/0039p1_1_0_4.png
# Test/0/0032p1_3_0_2.png
# Test/0/0031f1_3_0_1.png
# Test/0/0034p1_3_0_3.png
# Test/0/0034t1_2_0_4.png
# Test/0/0033f1_2_0_1.png
# Test/0/0032t1_4_0_3.png
# Test/0/0039n1_2_0_2.png
# Test/0/0035p1_3_0_2.png
# Test/0/0034t1_1_0_4.png
# Test/0/0036t1_2_0_4.png
# Test/0/0033f1_3_0_4.png
# Test/0/0033t1_3_0_1.png
# Test/0/0037p1_1_0_2.png
# Test/0/0039p1_3_0_4.png
# Test/0/0036p1_4_0_2.png
# Test/0/0031t1_1_0_3.png
# Test/0/0036p1_2_0_2.png
# Test/0/0033f1_1_0_4.png
# Test/0/0032p1_3_0_1.png
# Test/0/0032f1_3_0_3.png
# Test/0/0039n1_2_0_1.png
# Test/0/0038t1_1_0_4.png
# Test/0/0034t1_2_0_1.png
# Test/0/0031f1_4_0_3.png
# Test/0/0036p1_4_0_3.png
# Test/0/0033f1_1_0_1.png
# Test/0/0037t1_1_0_1.png
# Test/0/0032t1_4_0_2.png
# Test/0/0035p1_1_0_4.png
# Test/0/0035t1_4_0_1.png
# Test/0/0032p1_3_0_3.png
# Test/0/0033t1_4_0_1.png
# Test/0/0033f1_2_0_2.png
# Test/0/0035p1_3_0_1.png
# Test/0/0036p1_2_0_4.png
# Test/0/0037t1_1_0_3.png
# Test/0/0037p1_1_0_4.png
# Test/0/0033t1_3_0_4.png
# Test/0/0032p1_1_0_3.png
# Test/0/0035p1_1_0_3.png
# Test/0/0038t1_3_0_3.png
# Test/0/0037p1_3_0_2.png
# Test/0/0036t1_2_0_2.png
# Test/0/0036t1_2_0_1.png
# Test/0/0033f1_3_0_1.png
# Test/0/0033f1_2_0_3.png
# Train/1/0178b1_2_3_1_4.png
# Train/1/0069t1_1_1_1_5.png
# Train/1/0073t1_1_1_1_5.png
# Train/1/0105u1_4_1_1_4.png
# Train/1/0069t1_2_1_1_5.png
# Train/1/0072t1_4_1_1_5.png
# Train/1/0068b1_1_1_1_1.png
# Train/1/0074b1_2_1_1_5.png
# Train/1/0208u1_1_1_1_1.png
# Train/1/0077b1_4_1_1_3.png
# Train/1/0085t1_4_2_1_5.png
# Train/1/0162p1_2_1_1_3.png
# Train/1/0109u1_4_1_1_5.png
# Train/1/0165u1_2_1_1_2.png
# Train/1/0101u1_3_1_1_1.png
# Train/1/0161p1_1_1_1_3.png
# Train/1/0078b1_3_1_1_4.png
# Train/1/0219u1_4_1_1_5.png
# Train/1/0072t1_4_1_1_3.png
# Train/1/0072t1_4_1_1_2.png
# Train/1/0161p1_2_1_1_5.png
# Train/1/0289u1_6_1_1_5.png
# Train/1/0046u1_2_2_1_5.png
# Train/1/0078b1_1_1_1_1.png
# Train/1/0067b1_3_1_1_5.png
# Train/1/0091u1_1_2_1_5.png
# Train/1/0273n1_2_1_1_1.png
# Train/1/0077b1_3_1_1_5.png
# Train/1/0077b1_1_1_1_2.png
# Train/1/0041t1_2_1_1_1.png
# Train/1/0162p1_1_1_1_4.png
# Train/1/0116u1_3_1_1_5.png
# Train/1/0222u1_2_1_1_5.png
# Train/1/0042t1_1_1_1_5.png
# Train/1/0101u1_4_1_1_4.png
# Train/1/0088u1_1_1_1_3.png

# %% [markdown]
# We can show all files and folders in a certain path using ```ls```.

# %%
# !ls
# Out:
# DL_class_data.tar.gz  README_micro.rtf	sample_data  Test  Train

# %%
# !ls Train/
# Out:
# 0  1

# %% [markdown]
# Each folder should have mammogram images containing microcalcifications (label=1) or normal breast tissue (label=0) put in different subfolders.

# %%
# !ls {Test,Train}
# Out:
# Test:
# 0  1
#
# Train:
# 0  1

# %% [markdown]
# Remember that microcalcification clusters have label=1 and  normal breast tissue label=0. \\
# The number of images for each folder should be as it follows:
# ```
# Train 0 files: 289
# Train 1 files: 267
# Test 0 files: 125
# Test 1 files: 116
# ```

# %% [markdown]
# You can check it with the following commands:

# %%
# !echo -n "Train 0 files: "; ls Train/0 | wc -l;
# !echo -n "Train 1 files: "; ls Train/1 | wc -l;
# !echo -n "Test 0 files: "; ls Test/0 | wc -l;
# !echo -n "Test 1 files: "; ls Test/1 | wc -l;
# Out:
# Train 0 files: 289
# Train 1 files: 267
# Test 0 files: 125
# Test 1 files: 116

# %% [markdown]
# You can print, for example, the filenames of the last three file  inside a folder, with the following instruction:

# %%
# !ls Train/1/ | tail -n 3
# Out:
# 0312u1_1_1_1_5.png
# 0313u1_1_1_1_5.png
# 0313u1_1_2_1_5.png

# %% [markdown]
# # Reading the images

# %% [markdown]
# We need to import some python packages (matplotlib, os, glob, numpy) and to install and import scikit-image to read and visualize images.

# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (0.19.3)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.23.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1
# We can define a function to read images from a certain ```dataset_path``` and ```classes``` that matches the subfolders containing labeled images.
#
# The function uses the ```glob``` functions that finds all the pathnames that match a given pattern [[doc](https://docs.python.org/3/library/glob.html)].
# The images are read though the package ```imread``` [[doc](https://scikit-image.org/docs/dev/api/skimage.io.html#skimage.io.imread)]. This list of read images is populated with list comprehensions [[doc](https://docs.python.org/3/tutorial/datastructures.html#list-comprehensions)].
#
# The last line converts the ```tmp``` list into a numpy array storing float32 data, adding an extra dimension with ```np.newaxis``` [[doc](https://numpy.org/doc/stable/reference/constants.html#numpy.newaxis)] (the three dots ```...``` are a special indexing symbol called ellipsis [[doc](https://docs.python.org/dev/library/constants.html#Ellipsis)])

# %%
def read_imgs(dataset_path, classes):
  tmp = []
  labels = []
  for cls in classes:
    # Returns all the images filenames contained in a certain folder
    fnames = glob.glob(os.path.join(dataset_path, str(cls), '*.png'))
    # Read, with a list comprehension, all the images listed before
    tmp += [ imread(fname) for fname in fnames ]
    # Populate the labels list with the label of the read image
    labels += len(fnames)*[cls]

  return np.array(tmp, dtype='float32')[..., np.newaxis]/255, np.array(labels)

# %% [markdown]
# We can use the ```read_imgs```
# function to read all images in the dataset and store them in a numpy array, and to generate the appropriate numpy arrays with the labels corresponding to each instance.

# %%
train_dataset_path = 'Train'
x_train, y_train = read_imgs(train_dataset_path, [0, 1])

test_dataset_path = 'Test'
x_test, y_test = read_imgs(test_dataset_path, [0, 1])

# %% [markdown]
# It is always a good idea to print the shape of the array in use to check it. \
# *x_train* is the array of the images, in our case the first dimension is the number of read images, the second and the third are the dimensions of each image, and the last one represents the color channel: (sample_dimension, image_width, image_height, color_channel).
# While *y_train* is the array containing the label of each image (0 or 1).

# %%
#FILL HERE# Print the shape of the train and test arrays and their labels
#print(...)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (556, 60, 60, 1) (556,)
# (241, 60, 60, 1) (241,)

# %% [markdown]
# Plot the first image in the dataset using the *imshow* function of *matplotlib.pyplot*

# %%
#We select the first image of the array (you can choose a different one)
img_1 = x_train[0].reshape(60,60)

#FILL HERE#-> Display the image using imshow.
#You can also choose an appropriate colormap (cmap)
#plt...
plt.imshow(img_1, cmap='gray')

# %% [markdown]
# # Defining a CNN model

# %% [markdown]
# Convolutional neural networks (CNN) are a class of neural networks usually used to classify images.
# [[Ref1](https://www.asimovinstitute.org/neural-network-zoo/) ,
# [Ref2](https://www.freecodecamp.org/news/an-intuitive-guide-to-convolutional-neural-networks-260c2de0a050/)]
#
# ![dobVrh3SGyqQraM2ogi-P3VK2K-LFsBm7RLO.png](data:image/png;base64,...)
#
# [Ref3](https://towardsdatascience.com/building-a-convolutional-neural-network-cnn-in-keras-329fbbadc5f5)

# %% [markdown]
# - In CNN, the nodes of the convolutional layers  are not connected to all nodes of previous layer. This is due to the high dimesionality of image data. For this reason we connect each node only to a local region of the input.
#
# - The nodes are called neurons or filter or kernel. The nodes/filters are convolved to the network layers and they slide through the whole image in order to cover all pixels.

# %% [markdown]
# ![1*0R11RGqX9mM-YdxNgZ0V6A.jpeg](data:image/jpeg;base64,...)
#
# - Pooling layers. Pooling is a way to downsample the image: a common pooling technique is the "max pooling". A max pooling layer takes, for example, a 2x2 submatrix and returns the pixel with the maximum value
# [[doc](https://keras.io/api/layers/pooling_layers/max_pooling2d/)].

# %% [markdown]
# The Keras library in Python makes it pretty simple to build a CNN.
#
# - Models on Keras can be defined in two ways: sequential and functional. In the Sequential model, you define the model using a plain stack of layers and each layer has exactly one input and one output. In the functional one, each layer is defined as a function which can take as input the output of the previous layer. It allows also to merge, add and concatenate more than input.
#
#
# - Convolution layer
# > - The first layer takes in an input shape. This is the shape of each input image.
# > - Number of nodes in each layer `(8,16,32) `
# > - Kernel size is the size of the filter matrix for our convolution. So a kernel size of 3 means we will have a 3x3 filter matrix.
# > - What is the effect of using "padding = same"?
#
#
# > - Activation is the activation function for the layer. (ReLU or Rectified Linear Activation has been proven to work well in neural networks)
#
# - 'Batch normalization' adds a ‘normalization layer’ after each convolutional layer. This allows the model to converge much faster in training and to generalize better.
#
# - ‘Dense’ is the layer we will use just before the output layer. It is a fully connected layer typical of a Multi Layer Perceptrons model.
#
# - The last layer contains 1 node and a different activation function called "sigmoid". The sigmoid returns a probability distribution in the range of 0 to 1 (it is not the only possible activation!!!). The "sigmoid" is a good choice for the last layer for several reasons: 1) it is differentiable and monotonic, 2) it is a "smooth" function, 3) it simply exists between 0 and 1. However, it has also three main drowbacks: it returns predictions that are not zero-centered and it is computationally expensive; the third disadvantage, which is the reason why it is used only in the last layer, is that it may cause the "vanishing gradient". Why it may cause the vanishing gradient? Why is there just 1 node in the last layer? Is it possible to use another number of nodes for this specific problem?
#
# \\
#
#
# To prevent over-fitting we will use dropout layers.
# Overfitting happens when your model fits too well to the training set. It then becomes difficult for the model to generalize.
# Dropout works by stochastically removing, or “dropping out,” some nodes.

# %% [markdown]
# You can built your the CNN model using either the [sequential](https://keras.io/guides/sequential_model/) or the [functional](https://keras.io/guides/functional_api/) Keras API
# ([Keras Sequential and Functional Models example](https://machinelearningmastery.com/keras-functional-api-deep-learning/))

# %%
#FILL HERE# Import the keras.models according to the API you prefer
#from keras.models import ...
from tensorflow.keras.models import Sequential


#FILL HERE# Import all layers which are needed to build your CNN
#from keras.layers import ...
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Dense, Flatten, InputLayer, Activation, Dropout

# %% [markdown]
# Create a CNN with approximately the following structure:

# %%
#_________________________________________________________________
#Layer (type)                 Output Shape
#=================================================================
#conv2d (Conv2D)              (None, 60, 60, num_filters)
#_________________________________________________________________
#batch_normalization (BatchNo (None, 60, 60, num_filters)
#_________________________________________________________________
#activation (Activation)      (None, 60, 60, num_filters)
#_________________________________________________________________
#max_pooling2d (MaxPooling2D) (None, xxx, xxx, num_filters)

# …. ADD 3-4 BLOCKS AT MOST CONTAINING conv2d, batch_normalization, activation, max_pooling2d LAYERS

#flatten (Flatten)            (None, xxx)
#_________________________________________________________________
#dense (Dense)                (None, num_nodes)
#_________________________________________________________________
#dropout (Dropout)            (None, xxx)
#_________________________________________________________________
#dense_1 (Dense)              (None, num_nodes)
#=================================================================

# %% [markdown]
# You have to arbitrarily choose a number of free parameters to build your model. Check the Keras documentation for each type of [layer](https://keras.io/api/layers/).

# %%
#FILL HERE# Build you CNN

#Solution for sequential model (the best performing so far)
def make_model(shape=(60, 60, 1)):
  model = Sequential([

      Conv2D(8, (3,3), padding='same', input_shape=shape),
      BatchNormalization(),
      Activation('relu'),

      MaxPool2D((2,2), strides=2),
      #Dropout(0.4),

      Conv2D(16, (3,3), padding='same'),
      BatchNormalization(),
      Activation('relu'),

      MaxPool2D((2,2), strides=2),
      #Dropout(0.4),

      Conv2D(32, (3,3), padding='same'),
      BatchNormalization(),
      Activation('relu'),

      MaxPool2D((2,2), strides=2),
      #Dropout(0.4),

      Flatten(),    #Flatten serves as a connection between the convolution and dense layers.

      Dense(10, activation='relu'),
      Dropout(0.2),
      Dense(1, activation='sigmoid')

  ])
  return model

model = make_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 60, 60, 8)         80
#
#  batch_normalization (Batch  (None, 60, 60, 8)         32
#  Normalization)
#
#  activation (Activation)     (None, 60, 60, 8)         0
#
#  max_pooling2d (MaxPooling2  (None, 30, 30, 8)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 16)        1168
#
#  batch_normalization_1 (Bat  (None, 30, 30, 16)        64
#  chNormalization)
#
#  activation_1 (Activation)   (None, 30, 30, 16)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 15, 15, 16)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 32)        4640
#
#  batch_normalization_2 (Bat  (None, 15, 15, 32)        128
#  chNormalization)
#
#  activation_2 (Activation)   (None, 15, 15, 32)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense (Dense)               (None, 10)                15690
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 21813 (85.21 KB)
# Trainable params: 21701 (84.77 KB)
# Non-trainable params: 112 (448.00 Byte)
# _________________________________________________________________

# %% [markdown]
# You can plot your model also with the [*plot_model*](https://keras.io/api/utils/model_plotting_utils/) function

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# Next, we need to compile our model. Compiling the model takes three parameters: optimizer, loss and metrics.
# - The loss function ‘binary_crossentropy’ is the most common choice for classification and represents the function we want to minimize.
# - The optimizer is the algorithm procedure for minimizing the loss. A pivotal parameter of the optimizer is the learning rate which is the step size made by the loss function towards its minimum.\
# Several optimizers are available in keras, for example SGD and ADAM [[doc](https://keras.io/api/optimizers/)]. You can try to compare them.
#
# - We will use the ‘accuracy’ metric to measure the model classification performance on both the validation set (during training) and the test set.

# %%
#FILL HERE# You have to choose the optimizer, loss function and evaluation metrics, and to compile the model
#from keras.optimizers import ...
#model.compile(...)
from tensorflow.keras.optimizers import SGD #stochastic gradient descent
learning_rate = 0.001
model.compile(optimizer=SGD(learning_rate, momentum=0.9), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #Defining the Training, Validation and Independent Test sets
#
# When we load the data, we defined the *Train* and *Test* sets as a fixed split of our entire sample.
# We will leave the *Test* apart form the model training and use it at the end of the exercise to provide our *best classification result* on this *Independent Test set*. We can compare this result for example with those achieved by the other Hackathon groups.
#
# We will use only the *Train* set during the model training. However, before we start to train our CNN model, we have to define a further split of the *Train* set into a *train* (again!) and a *validation* set. \
# During the model training phase, the model parameters are estimated on the *train* set and the model is evaluated on the *validation* set.\
# By comparing the performance that different models obtain on the *validation* set, we can select the best model to finally evaluate on the *Independent Test* set.
#
# We can for example assign the 90% of the sample to the *train* and the 10% to the *validation* set.
#
#
# To split the *Train* set into the *train* and *validation* sets we can use the *train_test_split* function of *sklearn.model_selection* to carry out this task. *train_test_split* splits data arrays into two subsets. By default,it will make random partitions for the two subsets [[doc](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)].

# %% [markdown]
# Rndom state :

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(x_train, y_train, test_size=0.1, random_state=53)
# we can specify a random_state to mantain the train_test_split fixed in order to compare different model we bouild on the same validation set
#FILL HERE# Print the shape of train and validation arrays
#print(...)
#print(...)
print(np.shape(X_train), np.shape(Y_train))
print(np.shape(X_val), np.shape(Y_val))
# Out:
# (500, 60, 60, 1) (500,)
# (56, 60, 60, 1) (56,)

# %% [markdown]
# #Training the model

# %% [markdown]
# During the model training we can use a callback.\
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
# [[doc](https://keras.io/api/callbacks/)]. \
# In this exercise, we will use the *ReduceLROnPlateau* to reduce the learning rate during the training. In general, in fact, training a neural network means to search for the minimum of the loss functions changing a high number of parameters. It may happen that, after a certain number of epochs, the loss function can not decrease anymore since it has reached a local minumum. The loss function (as well as the metric/accuracy) hence reaches a plateau. In order to let the loss function further decrease, we can decrease the learning rate: the step made by the loss function is, then, smaller and it is possibile to find a minimum, improving the network performance.\
# One of the most used callbacks is the "ModelCheckpoint" one. It allows to save the model during the training and you can choose the conditions under which it works. To make this exercise simpler, you will not use it but we want to underline that often it is mandatory.

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
checkpoint = ModelCheckpoint(
    "model-{epoch:02d}-{val_accuracy:.2f}.keras",
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    save_weights_only=False,
    mode='auto', save_freq='epoch')

reduce_on_plateau = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.1,
    patience=10,
    verbose=0,
    mode="auto",
    min_delta=0.0001,
    cooldown=0,
    min_lr=0)

# %% [markdown]
# To train the model, we will use the ‘fit()’ function with the following parameters: training data (x_tain), target data (y_train), validation data, and the number of epochs.\
# "fit()" will train the model by dividing the data into "batch", and repeatedly iterating over the entire data set for a given number of epochs [[doc](https://keras.io/api/models/model_training_apis/)]. A batch is a small subsample of data and its introduction allows a better generalization. It also reduces the training time because the network parameters are updatated for each batch instead of updating them for each image.

# %%
#FILL HERE#
#epochs= #FILL HERE# # You can start from 50-100, then try to augment
#batch_size = 32 #32 is a good starting point, if you want, try other numbers: 64, 128
#history = model.fit( ...
#                    batch_size=...
#                    epochs=...
#                    step_per_epoch=...
#                    validation_data=(X_val, Y_val),
#                    validation_steps=np.shape(X_val)[0]/batch_size,
#                    callbacks=[checkpoint,reduce_on_plateau]
#                    )
epochs= 200 # 300 is ok
batch_size = 16
history = model.fit(X_train, Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    steps_per_epoch = np.shape(X_train)[0]//batch_size,
                    verbose=1,
                    validation_data=(X_val, Y_val),
                    validation_steps=np.shape(X_val)[0]//batch_size,
                    callbacks=[checkpoint,reduce_on_plateau]
                    )
# Out:
# Epoch 1/200
# 32/31 [==============================] - ETA: 0s - loss: 0.6335 - accuracy: 0.6980
# Epoch 1: val_accuracy improved from -inf to 0.53571, saving model to model-01-0.54.h5
# 31/31 [==============================] - 12s 32ms/step - loss: 0.6335 - accuracy: 0.6980 - val_loss: 0.6868 - val_accuracy: 0.5357 - lr: 0.0010
# Epoch 2/200
# 23/31 [=====================>........] - ETA: 0s - loss: 0.4931 - accuracy: 0.7500
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_accuracy did not improve from 0.53571
# 31/31 [==============================] - 0s 6ms/step - loss: 0.5012 - accuracy: 0.7560 - val_loss: 0.6815 - val_accuracy: 0.5357 - lr: 0.0010
# Epoch 3/200
# 32/31 [==============================] - ETA: 0s - loss: 0.4635 - accuracy: 0.7700
# Epoch 3: val_accuracy did not improve from 0.53571
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4635 - accuracy: 0.7700 - val_loss: 0.6852 - val_accuracy: 0.5357 - lr: 0.0010
# Epoch 4/200
# 30/31 [===========================>..] - ETA: 0s - loss: 0.4068 - accuracy: 0.8146
# Epoch 4: val_accuracy did not improve from 0.53571
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4081 - accuracy: 0.8140 - val_loss: 0.7020 - val_accuracy: 0.5357 - lr: 0.0010
# Epoch 5/200
# 32/31 [==============================] - ETA: 0s - loss: 0.4269 - accuracy: 0.8240
# Epoch 5: val_accuracy did not improve from 0.53571
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4269 - accuracy: 0.8240 - val_loss: 0.6942 - val_accuracy: 0.5357 - lr: 0.0010
# Epoch 6/200
# 32/31 [==============================] - ETA: 0s - loss: 0.4050 - accuracy: 0.8240
# Epoch 6: val_accuracy did not improve from 0.53571
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4050 - accuracy: 0.8240 - val_loss: 0.7208 - val_accuracy: 0.5357 - lr: 0.0010
# Epoch 7/200
# 22/31 [====================>.........] - ETA: 0s - loss: 0.3993 - accuracy: 0.8352
# Epoch 7: val_accuracy did not improve from 0.53571
# 31/31 [==============================] - 0s 7ms/step - loss: 0.3971 - accuracy: 0.8320 - val_loss: 0.7028 - val_accuracy: 0.5357 - lr: 0.0010
# Epoch 8/200
# 30/31 [===========================>..] - ETA: 0s - loss: 0.3886 - accuracy: 0.8479
# Epoch 8: val_accuracy did not improve from 0.53571
val_accuracy did not improve from 0.96429
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1224 - accuracy: 0.9600 - val_loss: 0.1607 - val_accuracy: 0.9286 - lr: 1.0000e-15
# Epoch 195/200
# 31/31 [============================>.] - ETA: 0s - loss: 0.1509 - accuracy: 0.9415
# Epoch 195: val_accuracy did not improve from 0.96429
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1507 - accuracy: 0.9420 - val_loss: 0.1606 - val_accuracy: 0.9286 - lr: 1.0000e-15
# Epoch 196/200
# 28/31 [=========================>....] - ETA: 0s - loss: 0.1199 - accuracy: 0.9643
# Epoch 196: val_accuracy did not improve from 0.96429
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1168 - accuracy: 0.9640 - val_loss: 0.1607 - val_accuracy: 0.9286 - lr: 1.0000e-15
# Epoch 197/200
# 26/31 [=======================>......] - ETA: 0s - loss: 0.1212 - accuracy: 0.9688
# Epoch 197: val_accuracy did not improve from 0.96429
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1206 - accuracy: 0.9700 - val_loss: 0.1614 - val_accuracy: 0.9286 - lr: 1.0000e-15
# Epoch 198/200
# 31/31 [============================>.] - ETA: 0s - loss: 0.1114 - accuracy: 0.9677
# Epoch 198: val_accuracy did not improve from 0.96429
# 31/31 [==============================] - 0s 7ms/step - loss: 0.1110 - accuracy: 0.9680 - val_loss: 0.1613 - val_accuracy: 0.9286 - lr: 1.0000e-15
# Epoch 199/200
# 28/31 [=========================>....] - ETA: 0s - loss: 0.1413 - accuracy: 0.9442
# Epoch 199: val_accuracy did not improve from 0.96429
# 31/31 [==============================] - 0s 7ms/step - loss: 0.1465 - accuracy: 0.9420 - val_loss: 0.1613 - val_accuracy: 0.9286 - lr: 1.0000e-16
# Epoch 200/200
# 31/31 [============================>.] - ETA: 0s - loss: 0.1296 - accuracy: 0.9657
# Epoch 200: val_accuracy did not improve from 0.96429
# 31/31 [==============================] - 0s 7ms/step - loss: 0.1313 - accuracy: 0.9640 - val_loss: 0.1619 - val_accuracy: 0.9286 - lr: 1.0000e-16

# %% [markdown]
# # Visualize the model training history

# %% [markdown]
# Plot accuracy and loss curves on the *train* and *validation* sets over the training epochs [docs](https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/).

# %%
#FILL HERE#
#acc = history.history['accuracy']
#val_acc = history.history['val_accuracy']
#loss = history.history['loss']
#val_loss = history.history['val_loss']

#epochs_range = range(1, len(acc)+1)
#Train and validation accuracy
#plt.figure(figsize=(15, 15))
#plt.subplot(2, 2, 1)
#plt.plot(..
#plt.plot(..
#Train and validation loss
#plt.subplot(2, 2, 2)
#plt.plot(..
#plt.plot(..


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(acc)+1)
#Train and validation accuracy
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
#Train and validation loss
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Evaluate the network performance on **validation** data.
# Keras model provides a function that evaluate the model on new datasets. It has three main arguments: data, data label, verbose (true or false)[[doc](https://keras.io/api/models/model_training_apis/)].

# %%
#FILL HERE# Evaluate the model on the validation set and print the accuracy value achieved
#_, val_acc = model.evaluate(...
#print(...
_, val_acc = model.evaluate(X_val, Y_val, verbose=0)
print('Validation accuracy: %.3f' % (val_acc))
# Out:
# Validation accuracy: 0.929

# %% [markdown]
# # ROC curve
# Create the ROC curve [[doc](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)] and compute the Area Under the Curve AUC (the false-positive rate and the true-positive rate) [[doc](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.auc.html)]. \\
# [Receiver Operating Characteristic (ROC)](https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#sphx-glr-auto-examples-model-selection-plot-roc-py). \
# ROC curve is typically used in binary classification to depict the trade-off between the system sensitivity and the rate of false-positive detections of the output of a classifier obtained by varing the decision threshold. The AUC value is a useful global number to compare the performance of different classifiers.

# %%
from sklearn.metrics import roc_curve, auc
preds = model.predict(X_val, verbose=1)

#Compute Receiver operating characteristic (ROC)
fpr, tpr, _ = roc_curve(Y_val, preds)

roc_auc = auc(fpr, tpr)
#Plot of a ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# 2/2 [==============================] - 0s 6ms/step

# %% [markdown]
# Now that you have evaluated the classification performance in terms of AUC on the *validation* set you could:
# *   Try and evaluate different CNN architectures or different setting of free parameters and compare the performance achieved on the same validation set (the same validation set is obtained by explicitating a specific random_state in the *train_test_split* function)
# *   Otherwise, if you have already obtained quite stisfactory performance (e.g. AUC > 90%), you could run the training al least 5 times to evaluate the average and standard deviation on AUC induced by the sample variability (i.e. once the fixed random_state option is removed from the *train_test_split* function).
# *   When you are satisfied with your classification performance, you can choose your best model and move to next section and to evaluate it on the independent *Test* set.

# %% [markdown]
# #Saving the model

# %% [markdown]
# You can save a model you like to reuse it later on:

# %%
model.save('model.h5') # it just saves the model at the last epoch
#You can rename it by using shell command, e.g. !cp model.h5 model-random_state-24.h5
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# !ls
# Out:
# DL_class_data.tar.gz  model-11-0.73.h5	model-22-0.91.h5  model.h5	    Test
# model-01-0.54.h5      model-13-0.79.h5	model-28-0.93.h5  model.png	    Train
# model-09-0.66.h5      model-14-0.84.h5	model-61-0.95.h5  README_micro.rtf
# model-10-0.70.h5      model-17-0.89.h5	model-92-0.96.h5  sample_data

# %% [markdown]
# # Evaluate network performance on the independent **Test** set in term of accuracy and AUC.

# %%
#FILL HERE# Evaluate the model on the independent Test set (x_test, y_test)
# ....
# print(...)
test_loss, test_acc = model.evaluate(x_test, y_test)
print('\nTest accuracy: %.3f' % (test_acc))
# Out:
# 8/8 [==============================] - 0s 13ms/step - loss: 0.2172 - accuracy: 0.9170
#
# Test accuracy: 0.917

# %%
preds_test = model.predict(x_test, verbose=1)
fpr, tpr, _ = roc_curve(y_test, preds_test)
roc_auc = auc(fpr, tpr)
print('AUC = %.3f'% (roc_auc))
# Out:
# 8/8 [==============================] - 0s 2ms/step
# AUC = 0.976

# %%
#Plot of a ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Please report the Accuracy and AUC values you obtained on the *Test* set in the report by the group.

# %% [markdown]
# # Data augmentation [extra]
#
# For those of you that are very skilled and/or very fast we briefly treat the topic of data augmentation.
#
# Data augmentation is a techniqued used to increase the size of the training dataset images by artficially creating new imaging applying appropriate transformations.
#
# In order to perform the said modifications we use the ImageDataGenerator class [[doc](https://keras.io/api/preprocessing/image/)] of keras but first we need to convert the training dataset images to .png format using the Python Image Library (PIL [[doc](https://pillow.readthedocs.io/en/stable/)]).

# %%
import PIL

# %% [markdown]
# Data augmentation is particularly useful in the context of medical physics since data is usually scarce.
#
# We can then improve the overall performance of our CNN providing a greater number of images, even if they are generated from our starting dataset.
#
# As an example we show the process of generating new images by means of translation, scaling, and vertical and horizontal flips. These processes are very basic manipulation of images but lots of CNN can't really tell that the processed image came from the original one in our dataset.
#
# The following illustrations (curtesy of nanonets.com) show the effects of the said image manipulation:

# %% [markdown]
# *   Flip
#
# ![1_-beH1nNqlm_Wj-0PcWUKTw.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# *   Rotation
#
#
# ![1_i_F6aNKj3yggkcNXQxYA4A.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# *   Scale
#
#
# ![1_INLTn7GWM-m69GUwFzPOaQ.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# *   When the applied transformation leaves some blank areas the `fill_mode` define the way it is filled. The following image show the effects of `constant`, `edge`, `reflect`, `symmetric` and `wrap` modes
#
# ![1_rG4YJyVdu28LZwkwkwC55w.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# To carry out data augmentation we will use the
# ```ImageDataGenerator``` class of Keras [doc](https://keras.io/api/preprocessing/image/)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# We define the desidered image manipulations using the `flow_from_directory` method. The methods returns a DirectoryIterator yielding tuples of (x, y) where x is a numpy array containing a batch of images with shape (batch_size, *target_size, channels) and y is a numpy array of corresponding labels.

# %% [markdown]
# There are many augmentation options and related parameters you can play with.

# %%
train_dataset_path = 'Train'
img_width, img_height = (60, 60)

train_datagen = ImageDataGenerator(
        rotation_range=30,
        width_shift_range=0.1,
        height_shift_range=0.1,
        rescale=1./255,
        #shear_range=0.2,
        #zoom_range=0.18,
        horizontal_flip=True,
        #vertical_flip=True,
        fill_mode='reflect', #  nearest?
        validation_split=0.1)

train_gen = train_datagen.flow_from_directory(
    train_dataset_path,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    class_mode='binary',
    subset='training')

val_gen = train_datagen.flow_from_directory(
    train_dataset_path,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    class_mode='binary',
    subset='validation')
# Out:
# Found 502 images belonging to 2 classes.
# Found 54 images belonging to 2 classes.

# %% [markdown]
# Let's print the shape of the DirectoryIterator and get, each time, a new batch [[doc](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/DirectoryIterator)]

# %%
train_gen.next()[0].shape
# Out:
# (32, 60, 60, 1)

# %%
plt.imshow(train_gen.next()[0][1].squeeze(), cmap='gray')

# %%
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(
    "model_augmented-{epoch:02d}-{val_accuracy:.2f}.h5",
    monitor='val_accuracy',
    verbose=1,
    save_best_only=False,
    save_weights_only=False,
    mode='auto', save_freq='epoch')

# %%
model = make_model()
learning_rate = 0.001
model.compile(optimizer=SGD(learning_rate, momentum=0.9), loss='binary_crossentropy', metrics=['accuracy'])

# %%
np.shape(X_train)[0], np.shape(X_val)[0]
# Out:
# (500, 56)

# %%
epochs=200 # 300 is ok
batch_size = 32
history = model.fit(train_gen,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=val_gen,
                    callbacks=[checkpoint, reduce_on_plateau])
# Out:
# Epoch 1/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6936 - accuracy: 0.5959
# Epoch 1: saving model to model_augmented-01-0.97.h5
# 15/15 [==============================] - 3s 75ms/step - loss: 0.6886 - accuracy: 0.6085 - val_loss: 0.6721 - val_accuracy: 0.9688 - lr: 0.0010
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2/200
# 15/15 [==============================] - ETA: 0s - loss: 0.5751 - accuracy: 0.6489
# Epoch 2: saving model to model_augmented-02-0.84.h5
# 15/15 [==============================] - 1s 41ms/step - loss: 0.5751 - accuracy: 0.6489 - val_loss: 0.6868 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 3/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5526 - accuracy: 0.6781
# Epoch 3: saving model to model_augmented-03-0.56.h5
# 15/15 [==============================] - 1s 54ms/step - loss: 0.5485 - accuracy: 0.6851 - val_loss: 0.6905 - val_accuracy: 0.5625 - lr: 0.0010
# Epoch 4/200
# 15/15 [==============================] - ETA: 0s - loss: 0.5604 - accuracy: 0.6574
# Epoch 4: saving model to model_augmented-04-0.56.h5
# 15/15 [==============================] - 1s 37ms/step - loss: 0.5604 - accuracy: 0.6574 - val_loss: 0.6890 - val_accuracy: 0.5625 - lr: 0.0010
# Epoch 5/200
# 15/15 [==============================] - ETA: 0s - loss: 0.5466 - accuracy: 0.7234
# Epoch 5: saving model to model_augmented-05-0.62.h5
# 15/15 [==============================] - 1s 42ms/step - loss: 0.5466 - accuracy: 0.7234 - val_loss: 0.6799 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 6/200
# 15/15 [==============================] - ETA: 0s - loss: 0.5376 - accuracy: 0.7167
# Epoch 6: saving model to model_augmented-06-0.56.h5
# 15/15 [==============================] - 1s 38ms/step - loss: 0.5376 - accuracy: 0.7167 - val_loss: 0.6786 - val_accuracy: 0.5625 - lr: 0.0010
# Epoch 7/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5144 - accuracy: 0.7534
# Epoch 7: saving model to model_augmented-07-0.50.h5
# 15/15 [==============================] - 1s 38ms/step - loss: 0.5136 - accuracy: 0.7553 - val_loss: 0.6689 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 8/200
# 15/15 [==============================] - ETA: 0s - loss: 0.4861 - accuracy: 0.7957
# Epoch 8: saving model to model_augmented-08-0.66.h5
# 15/15 [==============================] - 1s 40ms/step - loss: 0.4861 - accuracy: 0.7957 - val_loss: 0.6302 - val_accuracy: 0.6562 - lr: 0.0010
# Epoch 9/200
# 15/15 [==============================] - ETA: 0s - loss: 0.4809 - accuracy: 0.7511
# Epoch 9: saving model to model_augmented-09-0.56.h5
# Epoch 174/200
# 15/15 [==============================] - ETA: 0s - loss: 0.2525 - accuracy: 0.9149
# Epoch 174: saving model to model_augmented-174-0.94.h5
# 15/15 [==============================] - 1s 40ms/step - loss: 0.2525 - accuracy: 0.9149 - val_loss: 0.0949 - val_accuracy: 0.9375 - lr: 1.0000e-12
# Epoch 175/200
# 15/15 [==============================] - ETA: 0s - loss: 0.2120 - accuracy: 0.9167
# Epoch 175: saving model to model_augmented-175-0.94.h5
# 15/15 [==============================] - 1s 51ms/step - loss: 0.2120 - accuracy: 0.9167 - val_loss: 0.1545 - val_accuracy: 0.9375 - lr: 1.0000e-12
# Epoch 176/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2400 - accuracy: 0.9018
# Epoch 176: saving model to model_augmented-176-0.91.h5
# 15/15 [==============================] - 1s 60ms/step - loss: 0.2462 - accuracy: 0.8957 - val_loss: 0.1445 - val_accuracy: 0.9062 - lr: 1.0000e-13
# Epoch 177/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2321 - accuracy: 0.8927
# Epoch 177: saving model to model_augmented-177-0.94.h5
# 15/15 [==============================] - 1s 56ms/step - loss: 0.2274 - accuracy: 0.8936 - val_loss: 0.1531 - val_accuracy: 0.9375 - lr: 1.0000e-13
# Epoch 178/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2399 - accuracy: 0.9087
# Epoch 178: saving model to model_augmented-178-0.94.h5
# 15/15 [==============================] - 1s 63ms/step - loss: 0.2436 - accuracy: 0.9043 - val_loss: 0.1354 - val_accuracy: 0.9375 - lr: 1.0000e-13
# Epoch 179/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2438 - accuracy: 0.8973
# Epoch 179: saving model to model_augmented-179-1.00.h5
# 15/15 [==============================] - 1s 57ms/step - loss: 0.2563 - accuracy: 0.8957 - val_loss: 0.0438 - val_accuracy: 1.0000 - lr: 1.0000e-13
# Epoch 180/200
# 15/15 [==============================] - ETA: 0s - loss: 0.2226 - accuracy: 0.9234
# Epoch 180: saving model to model_augmented-180-0.97.h5
# 15/15 [==============================] - 1s 42ms/step - loss: 0.2226 - accuracy: 0.9234 - val_loss: 0.1069 - val_accuracy: 0.9688 - lr: 1.0000e-13
# Epoch 181/200
# 15/15 [==============================] - ETA: 0s - loss: 0.2461 - accuracy: 0.9064
# Epoch 181: saving model to model_augmented-181-0.97.h5
# 15/15 [==============================] - 1s 40ms/step - loss: 0.2461 - accuracy: 0.9064 - val_loss: 0.0878 - val_accuracy: 0.9688 - lr: 1.0000e-13
# Epoch 182/200
# 15/15 [==============================] - ETA: 0s - loss: 0.2312 - accuracy: 0.9125
# Epoch 182: saving model to model_augmented-182-0.97.h5
# 15/15 [==============================] - 1s 40ms/step - loss: 0.2312 - accuracy: 0.9125 - val_loss: 0.0894 - val_accuracy: 0.9688 - lr: 1.0000e-13
# Epoch 183/200
# 15/15 [==============================] - ETA: 0s - loss: 0.2383 - accuracy: 0.9234
# Epoch 193/200
# 15/15 [==============================] - ETA: 0s - loss: 0.2664 - accuracy: 0.8809
# Epoch 193: saving model to model_augmented-193-0.97.h5
# 15/15 [==============================] - 1s 42ms/step - loss: 0.2664 - accuracy: 0.8809 - val_loss: 0.0886 - val_accuracy: 0.9688 - lr: 1.0000e-14
# Epoch 194/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2251 - accuracy: 0.9132
# Epoch 194: saving model to model_augmented-194-1.00.h5
# 15/15 [==============================] - 1s 57ms/step - loss: 0.2229 - accuracy: 0.9128 - val_loss: 0.0549 - val_accuracy: 1.0000 - lr: 1.0000e-14
# Epoch 195/200
# 15/15 [==============================] - ETA: 0s - loss: 0.2147 - accuracy: 0.9106
# Epoch 195: saving model to model_augmented-195-0.91.h5
# 15/15 [==============================] - 1s 64ms/step - loss: 0.2147 - accuracy: 0.9106 - val_loss: 0.1566 - val_accuracy: 0.9062 - lr: 1.0000e-14
# Epoch 196/200
# 15/15 [==============================] - ETA: 0s - loss: 0.2140 - accuracy: 0.9191
# Epoch 196: saving model to model_augmented-196-0.91.h5
# 15/15 [==============================] - 1s 56ms/step - loss: 0.2140 - accuracy: 0.9191 - val_loss: 0.1380 - val_accuracy: 0.9062 - lr: 1.0000e-15
# Epoch 197/200
# 15/15 [==============================] - ETA: 0s - loss: 0.2515 - accuracy: 0.9021
# Epoch 197: saving model to model_augmented-197-0.97.h5
# 15/15 [==============================] - 1s 44ms/step - loss: 0.2515 - accuracy: 0.9021 - val_loss: 0.0849 - val_accuracy: 0.9688 - lr: 1.0000e-15
# Epoch 198/200
# 15/15 [==============================] - ETA: 0s - loss: 0.2373 - accuracy: 0.9213
# Epoch 198: saving model to model_augmented-198-0.97.h5
# 15/15 [==============================] - 1s 41ms/step - loss: 0.2373 - accuracy: 0.9213 - val_loss: 0.0946 - val_accuracy: 0.9688 - lr: 1.0000e-15
# Epoch 199/200
# 15/15 [==============================] - ETA: 0s - loss: 0.2295 - accuracy: 0.9106
# Epoch 199: saving model to model_augmented-199-0.94.h5
# 15/15 [==============================] - 1s 41ms/step - loss: 0.2295 - accuracy: 0.9106 - val_loss: 0.0824 - val_accuracy: 0.9375 - lr: 1.0000e-15
# Epoch 200/200
# 15/15 [==============================] - ETA: 0s - loss: 0.2230 - accuracy: 0.9106
# Epoch 200: saving model to model_augmented-200-0.94.h5
# 15/15 [==============================] - 1s 45ms/step - loss: 0.2230 - accuracy: 0.9106 - val_loss: 0.1042 - val_accuracy: 0.9375 - lr: 1.0000e-15

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(acc)+1)
#Train and validation accuracy
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
#Train and validation loss
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Saving the model

# %%
# !ls
# Out:
# DL_class_data.tar.gz	     model_augmented-147-0.94.h5  model_augmented-34-0.94.h5
# model-01-0.54.h5	     model_augmented-148-0.94.h5  model_augmented-35-1.00.h5
# model-09-0.66.h5	     model_augmented-149-0.94.h5  model_augmented-36-0.97.h5
# model-10-0.70.h5	     model_augmented-150-0.97.h5  model_augmented-37-0.94.h5
# model-11-0.73.h5	     model_augmented-15-0.53.h5   model_augmented-38-1.00.h5
# model-13-0.79.h5	     model_augmented-151-1.00.h5  model_augmented-39-0.91.h5
# model-14-0.84.h5	     model_augmented-152-0.97.h5  model_augmented-40-0.94.h5
# model-17-0.89.h5	     model_augmented-153-0.94.h5  model_augmented-41-0.81.h5
# model-22-0.91.h5	     model_augmented-154-0.97.h5  model_augmented-42-0.97.h5
# model-28-0.93.h5	     model_augmented-155-1.00.h5  model_augmented-43-0.97.h5
# model-61-0.95.h5	     model_augmented-156-0.97.h5  model_augmented-44-0.97.h5
# model-92-0.96.h5	     model_augmented-157-0.94.h5  model_augmented-45-0.94.h5
# model_augmented-01-0.97.h5   model_augmented-158-0.97.h5  model_augmented-46-0.94.h5
# model_augmented-02-0.84.h5   model_augmented-159-0.97.h5  model_augmented-47-0.91.h5
# model_augmented-03-0.56.h5   model_augmented-160-0.94.h5  model_augmented-48-0.91.h5
# model_augmented-04-0.56.h5   model_augmented-16-0.72.h5   model_augmented-49-0.94.h5
# model_augmented-05-0.62.h5   model_augmented-161-1.00.h5  model_augmented-50-0.97.h5
# model_augmented-06-0.56.h5   model_augmented-162-0.97.h5  model_augmented-51-0.97.h5
# model_augmented-07-0.50.h5   model_augmented-163-0.97.h5  model_augmented-52-0.97.h5
# model_augmented-08-0.66.h5   model_augmented-164-0.94.h5  model_augmented-53-0.97.h5
# model_augmented-09-0.56.h5   model_augmented-165-0.97.h5  model_augmented-54-0.97.h5
# model_augmented-100-1.00.h5  model_augmented-166-0.94.h5  model_augmented-55-1.00.h5
# model_augmented-10-0.69.h5   model_augmented-167-0.94.h5  model_augmented-56-1.00.h5
# model_augmented-101-1.00.h5  model_augmented-168-0.94.h5  model_augmented-57-1.00.h5
# model_augmented-102-0.97.h5  model_augmented-169-1.00.h5  model_augmented-58-0.97.h5
# model_augmented-103-0.97.h5  model_augmented-170-0.94.h5  model_augmented-59-0.94.h5
# model_augmented-104-0.97.h5  model_augmented-17-0.75.h5   model_augmented-60-0.97.h5
# model_augmented-105-0.97.h5  model_augmented-171-0.94.h5  model_augmented-61-1.00.h5
# model_augmented-106-0.97.h5  model_augmented-172-1.00.h5  model_augmented-62-0.97.h5
# model_augmented-107-0.94.h5  model_augmented-173-0.97.h5  model_augmented-63-0.94.h5
# model_augmented-108-0.94.h5  model_augmented-174-0.94.h5  model_augmented-64-0.97.h5
# model_augmented-109-0.94.h5  model_augmented-175-0.94.h5  model_augmented-65-0.97.h5
# model_augmented-110-0.94.h5  model_augmented-176-0.91.h5  model_augmented-66-1.00.h5
# model_augmented-11-0.72.h5   model_augmented-177-0.94.h5  model_augmented-67-0.97.h5
# model_augmented-111-0.97.h5  model_augmented-178-0.94.h5  model_augmented-68-0.97.h5
# model_augmented-112-1.00.h5  model_augmented-179-1.00.h5  model_augmented-69-0.97.h5
# model_augmented-113-0.97.h5  model_augmented-180-0.97.h5  model_augmented-70-0.97.h5
# model_augmented-114-0.97.h5  model_augmented-18-0.72.h5   model_augmented-71-0.97.h5
# model_augmented-115-0.91.h5  model_augmented-181-0.97.h5  model_augmented-72-0.97.h5
# model_augmented-116-0.97.h5  model_augmented-182-0.97.h5  model_augmented-73-1.00.h5
# model_augmented-117-0.97.h5  model_augmented-183-1.00.h5  model_augmented-74-1.00.h5
# model_augmented-118-0.94.h5  model_augmented-184-0.97.h5  model_augmented-75-0.94.h5
# model_augmented-119-0.94.h5  model_augmented-185-0.97.h5  model_augmented-76-1.00.h5
# model_augmented-120-1.00.h5  model_augmented-186-1.00.h5  model_augmented-77-1.00.h5
# model_augmented-12-0.69.h5   model_augmented-187-0.97.h5  model_augmented-78-0.97.h5
# model_augmented-121-0.97.h5  model_augmented-188-0.97.h5  model_augmented-79-1.00.h5
# model_augmented-122-1.00.h5  model_augmented-189-0.97.h5  model_augmented-80-0.97.h5
# model_augmented-123-0.94.h5  model_augmented-190-0.94.h5  model_augmented-81-1.00.h5
# model_augmented-124-0.97.h5  model_augmented-19-0.81.h5   model_augmented-82-0.97.h5
# model_augmented-125-0.94.h5  model_augmented-191-1.00.h5  model_augmented-83-0.97.h5
# model_augmented-126-1.00.h5  model_augmented-192-0.94.h5  model_augmented-84-0.97.h5
# model_augmented-127-0.97.h5  model_augmented-193-0.97.h5  model_augmented-85-1.00.h5
# model_augmented-128-0.94.h5  model_augmented-194-1.00.h5  model_augmented-86-0.97.h5
# model_augmented-129-0.97.h5  model_augmented-195-0.91.h5  model_augmented-87-0.97.h5
# model_augmented-130-0.97.h5  model_augmented-196-0.91.h5  model_augmented-88-0.97.h5
# model_augmented-13-0.59.h5   model_augmented-197-0.97.h5  model_augmented-89-0.97.h5
# model_augmented-131-0.94.h5  model_augmented-198-0.97.h5  model_augmented-90-0.97.h5
# model_augmented-132-0.97.h5  model_augmented-199-0.94.h5  model_augmented-91-1.00.h5
# model_augmented-133-0.97.h5  model_augmented-200-0.94.h5  model_augmented-92-0.97.h5
# model_augmented-134-1.00.h5  model_augmented-20-0.84.h5   model_augmented-93-0.97.h5
# model_augmented-135-1.00.h5  model_augmented-21-0.53.h5   model_augmented-94-0.94.h5
# model_augmented-136-0.97.h5  model_augmented-22-0.69.h5   model_augmented-95-0.97.h5
# model_augmented-137-1.00.h5  model_augmented-23-0.66.h5   model_augmented-96-0.97.h5
# model_augmented-138-0.94.h5  model_augmented-24-0.84.h5   model_augmented-97-0.97.h5
# model_augmented-139-0.97.h5  model_augmented-25-0.72.h5   model_augmented-98-0.91.h5
# model_augmented-140-0.97.h5  model_augmented-26-0.97.h5   model_augmented-99-0.94.h5
# model_augmented-14-0.69.h5   model_augmented-27-0.94.h5   model.h5
# model_augmented-141-0.94.h5  model_augmented-28-0.84.h5   model.png
# model_augmented-142-0.97.h5  model_augmented-29-0.91.h5   README_micro.rtf
# model_augmented-143-0.97.h5  model_augmented-30-0.88.h5   sample_data
# model_augmented-144-0.94.h5  model_augmented-31-0.94.h5   Test
# model_augmented-145-0.97.h5  model_augmented-32-0.94.h5   Train
# model_augmented-146-0.97.h5  model_augmented-33-0.94.h5

# %%
model.save('model_augmented.h5') # it just saves the model at the last epoch

# %%
from keras.models import load_model

# %% [markdown]
# Load the model with the best validation accuracy. To select the best model have a look at the names of the saved models (the last number is the accuracy on validation)

# %%
imported_model = load_model('model_augmented.h5')

# %%
imported_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 60, 60, 8)         80
#
#  batch_normalization_12 (Ba  (None, 60, 60, 8)         32
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 60, 60, 8)         0
#
#  max_pooling2d_12 (MaxPooli  (None, 30, 30, 8)         0
#  ng2D)
#
#  conv2d_13 (Conv2D)          (None, 30, 30, 16)        1168
#
#  batch_normalization_13 (Ba  (None, 30, 30, 16)        64
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 30, 30, 16)        0
#
#  max_pooling2d_13 (MaxPooli  (None, 15, 15, 16)        0
#  ng2D)
#
#  conv2d_14 (Conv2D)          (None, 15, 15, 32)        4640
#
#  batch_normalization_14 (Ba  (None, 15, 15, 32)        128
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 15, 15, 32)        0
#
#  max_pooling2d_14 (MaxPooli  (None, 7, 7, 32)          0
#  ng2D)
#
#  flatten_4 (Flatten)         (None, 1568)              0
#
#  dense_8 (Dense)             (None, 10)                15690
#
#  dropout_4 (Dropout)         (None, 10)                0
#
#  dense_9 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 21813 (85.21 KB)
# Trainable params: 21701 (84.77 KB)
# Non-trainable params: 112 (448.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Evaluate the performances of the two models

# %% [markdown]
# Load the models with and without augmentation which realized the best accuracy on validation

# %%
model = load_model('model.h5')
model_aug = load_model('model_augmented.h5')
#to select the best models have a look at the names of the saved models
#(the last number is the accuracy on validation)

# %%
x_test, y_test = read_imgs('Test', [0,1])

# %%
test_loss_noaug, test_acc_noaug = model.evaluate(x_test, y_test)
preds_test = model.predict(x_test, verbose=1)
fpr, tpr, _ = roc_curve(y_test, preds_test)
roc_auc = auc(fpr, tpr)

print('\n Test accuracy model no aug = %.3f'% (test_acc_noaug))
print('\n AUC = %.3f'% (roc_auc))
# Out:
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2172 - accuracy: 0.9170
# 8/8 [==============================] - 0s 3ms/step
#
#  Test accuracy model no aug = 0.917
#
#  AUC = 0.976

# %%
test_loss_aug, test_acc_aug = model_aug.evaluate(x_test, y_test) # both model should be evaluated on the Test set
preds_test_aug = model_aug.predict(x_test, verbose=1)
fpr_aug, tpr_aug, _ = roc_curve(y_test, preds_test_aug)
roc_auc_aug = auc(fpr_aug, tpr_aug)

print('\n Test accuracy aug model = %.3f'% (test_acc_aug))
print('\n AUC = %.3f'% (roc_auc_aug))
# Out:
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2503 - accuracy: 0.9212
# 8/8 [==============================] - 0s 3ms/step
#
#  Test accuracy aug model = 0.921
#
#  AUC = 0.971

# %% [markdown]
# Did you obtain an improvement of the performance on the *Test* set by using a data augmentation strategy?
